# %% [markdown]
# # Web Python Programming Term Project 1 Proposal

# %% [markdown]
# <li>StudentID: 2022104004</li>
# <li>Year: 2nd Year(2학년)</li>
# <li>Department: Industrial Management Engineering(산업경영공학과)</li>
# <li>Student Name: Tae Kyoung Lee(이태경)</li>

# %% [markdown]
# ## Contents

# %% [markdown]
# <details>
#     <summary><font size = 4 ><font color = '#FF8D33'> > See Contents </font></font></summary>
#     <ul>
#         <li> 1.1.1 Hypothesis Definition and Reasons </li>
#         <li> 1.1.2 Sources and Informations of Datasets </li>
#         <li> 1.1.3 References </li>
#     </ul>
# </details>

# %% [markdown]
# ### Hypothesis Definition and Reasons

# %% [markdown]
# <li><font color = '#FACC2E'><font size = 4> [Hypothesis 1]: Is the composite economic index in South Korea improving?</font></font> </li>
#
#      Supposition: It is currently improving
#
#
# <details>
#     <summary> >> Reason for defining Hypothesis 1 </summary>
#     <ul>
#     Understanding the current trends of the composite economic index is crucial for policymakers and economists. It helps in assessing the effectiveness of current economic policies and in planning future economic strategies.
#     </ul>
# </details>

# %% [markdown]
# <li> <font color = '#FACC2E'><font size = 4>[Hypothesis 2]: When is the density of fine dust the highest in Seoul?</font></font> </li>
#
#      Supposition: Highest during summer, and from 18:00~20:00.
#
# <details>
#     <summary> >> Reason for defining Hypothesis 2 </summary>
#     <ul>
# Fine dust is directly associated with various health issues, including respiratory and cardiovascular diseases. By undertaking this study, it's possible to identify the specific times and seasons when fine dust levels are at their highest. This information is vital for devising effective public health measures and advising the public on how to reduce exposure. This approach is particularly crucial in urban areas like Seoul, where environmental factors and high population density can greatly influence air quality and, consequently, public health.
#     </ul>
# </details>

# %% [markdown]
# <li> <font color = '#FACC2E'><font size = 4>[Hypothesis 3]: Which elements affect the house price the most? </font></font></li>
#
#      Supposition: Living Area, Built year, Bedrooms will be the most affective 3 elements
#
# <details>
#     <summary> >> Reason for defining Hypothesis 3 </summary>
#     <ul>
#        The real estate market is complex, and various factors influence housing prices. By identifying and analyzing these factors, we can gain a better understanding of the trends and mechanisms of the real estate market. This understanding provides crucial information for making real estate-related decisions and can also form the basis for predicting real estate prices.
#     </ul>

# %% [markdown]
# <li> <font color = '#FACC2E'><font size = 4>[Hypothesis 4]: Is the K-Online market growing? </font></font></li>
#
#      Supposition: It is growing as time passes
#
# <details>
#     <summary> >> Reason for defining Hypothesis 4 </summary>
#     <ul>
#     With the global shift towards digitalization, understanding the growth of K-Online Shopping Malls provides insights into current e-commerce trends, particularly in the context of South Korea's advanced digital infrastructure.
#     </ul>

# %% [markdown]
# ### Sources and Informations of Data

# %% [markdown]
# [국가통계포털](https://kosis.kr/statHtml/statHtml.do?orgId=301&tblId=DT_513Y001&vw_cd=MT_ZTITLE&list_id=J1_301025&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_ZTITLE&path=%252FstatisticsList%252FstatisticsListIndex.do)
#
#     Data from 1970~2023 about South Koreas's enconomic feature indexes
#
# [공공데이터 포털: 서울특별시_시간별 (초)미세먼지](https://www.data.go.kr/data/15089266/fileData.do)
#
#     Data from January 2008 to December 31, 2022, including district-specific time-averaged data along with the average data for Seoul City.
#
# [캐글: HOUSE_PRICE](https://www.kaggle.com/datasets/pritsheta/house-price)
#
#     Data on houses in the state of Washington, including information on prices, area, year of construction, and other details.
#
#
#
# [국가통계포털: 지역별/상품군별 온라인쇼핑 해외직접판매역](https://kosis.kr/statHtml/statHtml.do?orgId=301&tblId=DT_513Y001&vw_cd=MT_ZTITLE&list_id=J1_301025&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_ZTITLE&path=%252FstatisticsList%252FstatisticsListIndex.do)
#
#     Data about sellings for korean online shopping from 2014~2023

# %%
import pandas as pd

eco_df = pd.read_csv('./business_indicators.csv')
finedust_df = pd.read_csv('./finedust.csv',encoding = 'cp949')
house_price_df = pd.read_csv('./House-Price.csv')
shopping_df = pd.read_csv('./shopping.csv', encoding = 'cp949')

# %%
eco_df
# Out:
#             시점   선행종합지수(2020=100)   재고순환지표(%p)   경제심리지수  \
# 0      2019.01               94.8         -6.7     93.4
# 1      2019.02               95.0         -5.7     94.4
# 2      2019.03               95.3         -3.4     95.1
# 3      2019.04               95.5         -3.8     96.9
# 4      2019.05               95.6         -4.9     95.8
# 5      2019.06               95.6         -6.6     95.3
# 6      2019.07               95.7         -7.2     93.4
# 7      2019.08               95.9         -5.7     92.4
# 8      2019.09               96.3         -5.9     92.1
# 9      2019.10               96.9         -5.7     92.6
# 10     2019.11               97.5         -4.8     93.5
# 11     2019.12               98.0         -0.2     93.9
# 12     2020.01               98.3         -0.1     95.3
# 13     2020.02               98.6         -1.1     93.8
# 14     2020.03               98.5         -4.4     85.1
# 15     2020.04               98.5         -4.6     73.2
# ...

# %%
finedust_df
# Out:
#                       일시   구분  미세먼지(PM10)  초미세먼지(PM2.5)
# 0       2022-12-31 23:00   평균        59.0          46.0
# 1       2022-12-31 23:00  강남구        57.0          44.0
# 2       2022-12-31 23:00  강동구        68.0          55.0
# 3       2022-12-31 23:00  강북구        59.0          42.0
# 4       2022-12-31 23:00  강서구        62.0          40.0
# ...                  ...  ...         ...           ...
# 227755   2022-01-01 0:00  용산구        22.0          11.0
# 227756   2022-01-01 0:00  은평구        19.0           9.0
# 227757   2022-01-01 0:00  종로구        20.0           9.0
# 227758   2022-01-01 0:00   중구        20.0          11.0
# 227759   2022-01-01 0:00  중랑구        21.0           7.0
#
# [227760 rows x 4 columns]

# %%
house_price_df
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 0.00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 0.00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 0.00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 0.00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 0.00  5.500000e+05         4       2.50         1940
# ...               ...           ...       ...        ...          ...
# 4595  09-07-2014 0.00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 0.00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 0.00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 0.00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 0.00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
shopping_df
# Out:
#     지역별(1) 지역별(2) 지역별(3)     상품군별(1) 상품군별(2) 판매유형별(1) 2019.1/4 2019.2/4  \
# 0       합계     소계     소계          합계      소계        계  1251122  1345723
# 1       합계     소계     소계          합계      소계      면세점  1070693  1157158
# 2       합계     소계     소계          합계      소계   면세점 이외   180429   188565
# 3       합계     소계     소계  컴퓨터 및 주변기기      소계        계     3702     4038
# 4       합계     소계     소계  컴퓨터 및 주변기기      소계      면세점        2        0
# ..     ...    ...    ...         ...     ...      ...      ...      ...
# 964     기타     소계     소계    생활·자동차용품      소계      면세점        0        0
# 965     기타     소계     소계    생활·자동차용품      소계   면세점 이외      465      488
# 966     기타     소계     소계         기 타      소계        계      711      689
# 967     기타     소계     소계         기 타      소계      면세점        0        1
# 968     기타     소계     소계         기 타      소계   면세점 이외      711      688
#
#     2019.3/4 2019.4/4  ... 2021.2/4 2021.3/4 2021.4/4 2022.1/4 2022.2/4  \
# ...

# %% [markdown]
# ### References

# %% [markdown]
# [가설 1에 대한 근거 기사](https://www.etnews.com/20221201000063)
#
# [가설 2에 대한 근거 기사](https://www.etnews.com/20221201000063)
#
# [가설 3에 대한 근거 기사](https://www.cctoday.co.kr/news/articleView.html?idxno=2187569)
#
# [가설 4에 대한 근거 기사](http://www.cncnews.co.kr/news/article.html?no=8067)
